# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
model=load_model("fruit.h5")

# %%
img= image.load_img(r'C:\Users\dell\Desktop\Dataset Plant Disease\fruit-dataset\fruit-dataset\test\Peach___Bacterial_spot\0c148c6a-d3ea-44af-b52a-4ee596dce857___Rutg._Bact.S 1205.JPG',target_size=(128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2620356FEB0>

# %%
x= image.img_to_array(img)
x= np.expand_dims(x,axis=0)

# %%
pred= model.predict(x)
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
pred
# Out:
# array([[0., 0., 0., 0., 1., 0.]], dtype=float32)
